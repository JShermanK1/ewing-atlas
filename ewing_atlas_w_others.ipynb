# %%
import scanpy as sc
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import plotly.express as px
import seaborn as sns
from seaborn import (axes_style, plotting_context)
import sklearn.metrics as skm
import colorcet as cc
import sklearn as sk
import sklearn.decomposition as decomp
import sklearn.pipeline as pipe
import sklearn.neighbors as nbr
import sklearn.base as skbase
import sklearn.model_selection as skms
import pickle
import os
import joblib
import itertools
from pydeseq2.dds import DeseqDataSet as DDS
from pydeseq2.default_inference import DefaultInference
from pydeseq2.ds import DeseqStats as DS
import gseapy
import scanorama
import glob
import anndata as ann
import time


sns.set_style("whitegrid")
custom_cm = cc.m_CET_L17_r
custom_cm.set_extremes(under= "lightgrey")

def get_agg_groups(ann, groupby, resolution, key_added= "agg_groups"):
    """
    Use high resolution leiden clustering to aggregate cells

    Parameters
    ----------
    ann: Anndata
        The Anndata object to aggregate the observations of.
        ann is modified in place.
    groupby: str
        Column of ann.obs to aggregate within.
    resolution: float
        Resolution of leiden clustering. Higher value will produce more final groups.
    key_added: str
        Name of new column to add to ann.obs.
        Groups will be a set of categorical integer values that identify the clusters inside each value of groupby.
    """
    agg_groups = np.ndarray(ann.n_obs, dtype= int)
    for key, idx in ann.obs.groupby(groupby).indices.items():
        agg_groups[idx] = sc.tl.leiden(
            ann[idx],
            resolution= resolution,
            flavor= "igraph",
            key_added= key_added,
            copy= True
        ).obs[key_added].cat.codes
    ann.obs[key_added] = pd.Series(agg_groups, dtype= "category").values

# %%
os.makedirs(
    "figures",
    exist_ok= True,
)
os.makedirs(
    "pickles",
    exist_ok= True,
)
os.makedirs(
    "data",
    exist_ok= True
)
os.makedirs(
    "outputs/wgcna",
    exist_ok= True
)

# %%
files = glob.glob("Alex_Lemonade_portal/**/*_filtered*.h5ad", recursive= True)
datasets = [sc.read_h5ad(f) for f in files]
ids = ["sample" + f.split("/")[-1].split("_")[0][-3:] for f in files]
merged_data = ann.concat(
    datasets,
    merge= "first", 
    keys= ids, 
    label= "sample", 
    index_unique= "-"
)
merged_data.obs["age"] = merged_data.obs["age"].astype(float)
merged_data.obs = merged_data.obs.drop(columns= "subdiagnosis")
merged_data.var = merged_data.var.rename(columns= {"detected": "pct_cells_detected"})

# %%
sc.pl.violin(
    merged_data,
    ["sum", "detected", "subsets_mito_percent"],
    multi_panel= True,
    save= "_others_preproc.pdf",
    log= True,
)

# %%
mask = (merged_data.obs["sum"] > 100) \
        & (merged_data.obs["detected"] > 100) \
        & (merged_data.obs["subsets_mito_percent"] < 50)
merged_data = merged_data[mask, :].copy()
sc.pl.violin(
    merged_data,
    ["sum", "detected", "subsets_mito_percent"],
    multi_panel= True,
    save= "_others_preproc.pdf",
    log= True,
)

# %%
ax = sc.pl.violin(
    merged_data.transpose(),
    ["pct_cells_detected"],
    log= True,
)

# %%
merged_data = merged_data[:, merged_data.var["pct_cells_detected"] > 0.1].copy()
sc.pl.violin(
    merged_data.transpose(),
    ["pct_cells_detected"],
    log= True,
)

# %%
merged_data.var.info()

# %%
merged_data.var["gene_symbol"] = merged_data.var["gene_symbol"].astype("str")
merged_data.var.loc[merged_data.var["gene_symbol"] == "nan", "gene_symbol"] = merged_data.var.loc[merged_data.var["gene_symbol"] == "nan"].index
dupes = merged_data.var["gene_symbol"].duplicated()
merged_data.var.loc[dupes, "gene_symbol"] = merged_data.var.loc[dupes, "gene_symbol"].str.cat(
    merged_data.var.loc[dupes, "gene_ids"].astype(str).apply(lambda x: x[-6:]), sep= "-"
)

# %%
sc.pl.highest_expr_genes(
    merged_data,
    gene_symbols= "gene_symbol",
    save= True
)

# %%
sc.pp.highly_variable_genes(
    merged_data,
    n_top_genes= 2000,
    flavor= "seurat_v3",
)

sc.pl.highly_variable_genes(
    merged_data,
    save= True,
)

# %%
merged_data.var["mean"].sort_values(ascending= False)

# %%
merged_data = merged_data[:, merged_data.var["mean"] < 20]

sc.pp.highly_variable_genes(
    merged_data,
    n_top_genes= 2000,
    flavor= "seurat_v3",
)

sc.pl.highly_variable_genes(
    merged_data,
    save= True,
    log= True,
)

# %%
sc.pl.scatter(
    merged_data,
    "sum",
    "detected",
    color= "subsets_mito_percent",
    color_map= "viridis",
    save= "_others_sum_vs_detected.pdf"
)

# %%
merged_data.write_h5ad("data/merged_w_others_preproc.h5ad")

# %%
# !sbatch -c48 -p himem scripts/others_gs_sbatch.sh

# %%
merged_data = sc.read_h5ad("data/merged_w_others_preproc.h5ad")

# %%
merged_data = sc.read_h5ad("data/merged_w_others_filt.h5ad")
cox_model = pd.read_csv("../ewing_survival/outputs/cox_model_summary.csv")

# %%
merged_data.layers["norm"] = sc.pp.normalize_total(
    merged_data,
    copy= True,
    exclude_highly_expressed= True,
    key_added= "norm_factor",
).X

merged_data.layers["log"] = sc.pp.log1p(
    merged_data,
    copy= True,
    layer= "norm", 
).layers["norm"]


merged_data.layers["norm_scaled_genes"] = sc.pp.scale(
    merged_data,
    copy= True,
    layer= "log"
).layers["log"]

# %%
class ScPCA(skbase.TransformerMixin, skbase.BaseEstimator):
    def __init__(self, layer= None, n_comps= None, mask= None):
        self.layer = layer
        self.n_comps = n_comps
        self.mask = mask

    def fit(self, X, y= None):
        return self

    def transform(self, X):
        return sc.pp.pca(
            X,
            n_comps= self.n_comps,
            mask_var= self.mask,
            layer= self.layer,
            copy= True,
        )

class ScNeighbors(skbase.TransformerMixin, skbase.BaseEstimator):
    def __init__(self, n_neighbors= 15, n_pcs= None):
        self.n_neighbors = n_neighbors
        self.n_pcs = n_pcs

    def fit(self, X, y= None):
        return self
        
    def transform(self, X):
        return sc.pp.neighbors(
            X,
            n_neighbors= self.n_neighbors,
            n_pcs= self.n_pcs,
            copy= True,
        )
    
class ScLeiden(skbase.TransformerMixin, skbase.BaseEstimator):
    def __init__(self, resolution= 1):
        self.resolution = resolution

    def fit(self, X, y= None):
        return self

    def transform(self, X):
        return sc.tl.leiden(
            X,
            resolution= self.resolution,
            flavor= "igraph",
            copy= True,
        )

class ScScore(skbase.TransformerMixin, skbase.BaseEstimator):

    def fit(self, X, y= None):
        return self

    def score(estimator, X, y= None, sample_weight= None):
        return skm.silhouette_score(
            X.obsm["X_pca"],
            labels= X.obs["leiden"]
        )

# %%
with open("pickles/gridsearch_others_1000", mode= "br") as f:
    grids = pickle.load(f)

# %%
grids.best_params_

# %%
grids_df = pd.DataFrame({
    "n_neighbors": grids.cv_results_["param_scneighbors__n_neighbors"],
    "n_comps": grids.cv_results_["param_scpca__n_comps"],
    "resolution": grids.cv_results_["param_scleiden__resolution"],
    "iter": grids.cv_results_["iter"],
    "mean_test_score": grids.cv_results_["mean_test_score"],
})
grids_df["resolution"] = grids_df["resolution"].round(2)

# %%
combos = itertools.combinations(
    grids_df.columns.drop(["mean_test_score", "iter"]),
    r= 2
)
for combo in combos:
    dummy = grids_df.groupby(
        by= list(combo)
    ).agg(lambda x: np.nan).pivot_table(
        columns= combo[0],
        index=combo[1],
        values= "mean_test_score",
        dropna= False,
    )
    fig, axs = plt.subplots(
        ncols= grids_df["iter"].nunique(),
        figsize= (15, 5),
    ) 
    for i in grids_df["iter"].unique():
        data = grids_df.loc[grids_df["iter"] == i]
        sns.heatmap(
            dummy.fillna(data.groupby(
                by= list(combo)
            ).mean().pivot_table(
                columns= combo[0], 
                index= combo[1], 
                values= "mean_test_score"
            )),
            cmap= "cet_rainbow4",
            ax= axs[i]
        )
    fig.tight_layout()
    fig.savefig("figures/others_{}_{}_heatmap.pdf".format(combo[0], combo[1]), bbox_inches= "tight")
    plt.show()

# %%
ax = sns.boxplot(
    data,
    x= "resolution",
    y= "mean_test_score",
)
sns.stripplot(
    data,
    x= "resolution",
    y= "mean_test_score",
    alpha= 0.6,
    size= 3,
    ax= ax
)

# %%
def make_heatmap_df(data, **kwargs):
    heat_df = data.pivot_table(
        columns= "n_neighbors",
        index= "resolution",
        values= "mean_test_score",
        dropna= False,
    )
    sns.heatmap(
        heat_df,
        cmap= cc.rainbow4,
        annot= True,
        square= True,
        **kwargs,
    )

fg = sns.FacetGrid(
    data= data,
    col= "n_comps",
    col_wrap= 2,
    sharex= False,
    sharey= False,
    aspect= 2,
    height= 6,
)
fg.map_dataframe(
    make_heatmap_df,
    vmin= data["mean_test_score"].min(),
    vmax= data["mean_test_score"].max(),
)

# %%
data = grids_df.loc[grids_df["iter"] == grids_df["iter"].max()]
fig = px.scatter_3d(
    data,
    x= "n_comps",
    y= "n_neighbors",
    z= "resolution",
    color= "mean_test_score",
    color_continuous_scale= cc.rainbow4
)
fig.show()

# %%
sc.pp.pca(
    merged_data,
    layer= "norm_scaled_genes",
    mask_var= "highly_variable",
    n_comps= grids.best_params_["scpca__n_comps"],
)

sc.pl.pca_variance_ratio(
    merged_data,
    log= True
)

# %%
sc.pl.pca(
    merged_data,
    dimensions= [(0,1), (2, 3), (4, 5), (6, 7)],
    ncols= 2,
    color= "subsets_mito_percent"
)

# %%
sc.pp.neighbors(
    merged_data,
    n_neighbors= grids.best_params_["scneighbors__n_neighbors"],
)
sc.tl.leiden(
    merged_data,
    flavor= "igraph",
    resolution= grids.best_params_["scleiden__resolution"],
)
skm.silhouette_score(
    merged_data.obsm["X_pca"],
    labels= merged_data.obs["leiden"],
)

# %%
sc.tl.umap(
    merged_data,
    min_dist= 0.5,
    spread= 1.1
)

# %%
merged_data.obs["sum_log"] = np.log10(merged_data.obs["sum"])

# %%
with plotting_context("talk"):
    fig = sc.pl.umap(
        merged_data,
        color= [
            "tissue_location",
            "disease_timing",
            "subsets_mito_percent",
            "sum_log",
            "leiden",
            "diagnosis",
            "sample_id",
        ],
        gene_symbols= "gene_symbol",
        cmap= "jet",
        palette= cc.glasbey_category10,
        size= 5,
        ncols= 2,
        wspace= 0.4,
        return_fig= True,
        vmin= 0.1,
        alpha= 0.6,
    )
    for ax in fig.axes:
        ax.set_title(
            ax.get_title().replace("_", " ").title()
        )
    fig.savefig(
        "figures/overview_others_umap.png",
        bbox_inches= "tight",
    )

# %%
with plotting_context("talk"):
    fig = sc.pl.umap(
        merged_data,
        color= [
            "disease_timing",
            "leiden",
            "MACROH2A1",
            "MACROH2A2",
            "KDM1A",
            "FLI1",
            "diagnosis",
        ],
        gene_symbols= "gene_symbol",
        layer= "norm_scaled_genes",
        vmin= 0.1,
        cmap= custom_cm,
        palette= cc.glasbey_category10,
        size= 5,
        ncols= 2,
        wspace= 0.4,
        return_fig= True,
        alpha= 0.6,
    )
    for ax in fig.axes:
        if "_" in ax.get_title():
            ax.set_title(
                ax.get_title().replace("_", " ").title()
            )
    fig.savefig(
        "figures/others_goi_umap.png",
        bbox_inches= "tight",
    )

# %%
sc.tl.rank_genes_groups(
    merged_data,
    groupby= "leiden",
    layer= "log",
    method= "wilcoxon",
    mask_var= "highly_variable"
)

sc.tl.filter_rank_genes_groups(
    merged_data
)

# %%
sc.pl.rank_genes_groups(
    merged_data,
    gene_symbols= "gene_symbol",
    key= "rank_genes_groups"
)

# %%
sc.pl.rank_genes_groups_dotplot(
    merged_data,
    groupby= "leiden",
    gene_symbols= "gene_symbol",
    layer= "norm_scaled_genes",
    n_genes= 5,
    cmap= "bwr",
    save= "rank_genes_disease_timing.png",
    vcenter= 0,
)

# %%
idents = {
    "5": "Lung Epithilial",
    "6": "Immune",
    "7": "Endothelial",
    "4": "Fibroblasts",
}
merged_data.obs["tumor"] = ~merged_data.obs["leiden"].isin(idents.keys())
merged_data.obs["idents"] = merged_data.obs["leiden"]
merged_data.obs["idents"] = merged_data.obs["idents"].replace(idents)
merged_data.obs["idents"].unique()

# %%
sc.pl.umap(
    merged_data,
    color= [
        "idents",

    ],
    gene_symbols= "gene_symbol",
    cmap= custom_cm,
    palette= cc.glasbey_category10,
    vmin= 0.1,
    ncols= 3,
    size= 5,
    alpha= 0.6,
)

# %%
sc.pp.pca(
    merged_data,
    layer= "norm_scaled_genes",
    mask_var= "highly_variable",
    n_comps= 11,
)

sc.pl.pca_variance_ratio(
    merged_data,
    log= True
)

# %%
sc.pl.pca(
    merged_data,
    dimensions= [(0,1), (2, 3), (4, 5), (6, 7)],
    ncols= 2,
    color= "subsets_mito_percent"
)

# %%
sc.pp.neighbors(
    merged_data,
    n_neighbors= 45,
)
sc.tl.leiden(
    merged_data,
    flavor= "igraph",
    resolution= 0.76,
)
skm.silhouette_score(
    merged_data.obsm["X_pca"],
    labels= merged_data.obs["leiden"],
)

# %%
sc.tl.umap(
    merged_data,
    min_dist= 0.5,
    spread= 1.1
)

# %%
sc.pl.umap(
    merged_data,
    color= [
        "idents",
        "leiden",

    ],
    gene_symbols= "gene_symbol",
    cmap= custom_cm,
    palette= cc.glasbey_category10,
    vmin= 0.1,
    ncols= 3,
    size= 5,
    alpha= 0.6,
)

# %%
sc.tl.rank_genes_groups(
    merged_data,
    groupby= "leiden",
    layer= "log",
    method= "wilcoxon",
    mask_var= "highly_variable"
)

sc.tl.filter_rank_genes_groups(
    merged_data
)

# %%
sc.pl.rank_genes_groups(
    merged_data,
    gene_symbols= "gene_symbol",
    key= "rank_genes_groups"
)

# %%
sc.tl.dendrogram(
    merged_data,
    groupby= "leiden",
)
sc.pl.rank_genes_groups_dotplot(
    merged_data,
    groupby= "leiden",
    gene_symbols= "gene_symbol",
    layer= "norm_scaled_genes",
    n_genes= 5,
    cmap= "bwr",
    vcenter= 0,
    swap_axes= True,
)

# %%
idents = {
    "5": "Lung Epithilial",
    "7": "Immune",
    "8": "Endothelial",
    "6": "Fibroblasts",
    "0": "Fibrous Ewing",
    "2": "Neural Ewing",
    "13": "Skeletal Muscle",
    "15": "Neural Rhabdo",
    "14": "Initial Rhabdo",
    "16": "Mesenchymal Rhabdo",
    "9": "Ribosomal Rhabdo",
    "12": "Ribosomal Rhabdo",
    "18": "Ribosomal Ewing",
    "3": "FGF Ribo Ewing",
    "4": "Neural Ribo Ewing",
    "10": "Neural Reccurence Ewing",
    "11": "Initial DSRCT",
    "17": "Recurrence DSRCT",
    "1": "Recurrence Ewing",
}
merged_data.obs["tumor"] = ~merged_data.obs["leiden"].isin(["5", "7", "8", "6", "13"])
merged_data.obs["idents"] = merged_data.obs["leiden"]
merged_data.obs["idents"] = merged_data.obs["idents"].replace(idents)
merged_data.obs["idents"].unique()

# %%
with plotting_context("talk"):
    fig = sc.pl.umap(
        merged_data,
        color= [
            "disease_timing",
            "diagnosis",
            "tissue_location",
            "sample_id",
            "leiden",
            "idents",
            "subsets_mito_percent",
            "sum_log",
        ],
        gene_symbols= "gene_symbol",
        layer= "norm_scaled_genes",
        vmin= 0.1,
        cmap= "jet",
        palette= cc.glasbey_category10,
        size= 5,
        ncols= 2,
        wspace= 0.5,
        return_fig= True,
        alpha= 0.6,
    )
    for ax in fig.axes:
        ax.set_title(
            ax.get_title().replace("_", " ").title()
        )

# %%
with plotting_context("talk"):
    fig = sc.pl.umap(
        merged_data,
        color= [
            "disease_timing",
            "idents",
            "MACROH2A1",
            "MACROH2A2",
            "FLI1",
            "STAG2",
            "KDM1A",
            "FTL",
        ],
        gene_symbols= "gene_symbol",
        layer= "norm_scaled_genes",
        vmin= 0.1,
        cmap= custom_cm,
        palette= cc.glasbey_category10,
        size= 5,
        ncols= 2,
        wspace= 0.5,
        return_fig= True,
        alpha= 0.6,
    )
    for ax in fig.axes:
        if "_" in ax.get_title():
            ax.set_title(
                ax.get_title().replace("_", " ").title()
            )
    fig.savefig(
        "figures/others_goi_umap.png",
        bbox_inches= "tight",
    )

# %%
merged_data.uns["rank_genes_groups"] = None
merged_data.uns["rank_genes_groups_filtered"] = None

# %%
merged_data.write_h5ad("data/merged_w_others_filt.h5ad")

# %%
merged_data = sc.read_h5ad("data/merged_w_others_filt.h5ad")

# %%
get_agg_groups(merged_data, "idents", 100)

# %%
n_combicells = merged_data.obs.groupby(["idents", "agg_groups"]).size().groupby("idents").apply(
    lambda s: (s != 0).sum()
)
n_combicells

# %%
n_combicells.sum()

# %%
combicells = sc.get.aggregate(
    merged_data,
    by= ["agg_groups", "idents", "disease_timing", "diagnosis", "tissue_location"],
    func= "sum",
)
combicells

# %%
combicells.layers["norm"] = sc.pp.normalize_total(
    combicells,
    copy= True,
    exclude_highly_expressed= True,
    key_added= "norm_factor",
    layer= "sum",
).layers["sum"]

combicells.layers["log"] = sc.pp.log1p(
    combicells,
    copy= True,
    layer= "norm", 
).layers["norm"]


combicells.layers["norm_scaled_genes"] = sc.pp.scale(
    combicells,
    copy= True,
    layer= "log"
).layers["log"]

# %%
combicells.write_h5ad("data/combicells.h5ad")

# %%
get_agg_groups(
    merged_data,
    groupby= "idents",
    resolution= 0.5,
)
ident_samples = merged_data.obs.groupby(["idents", "agg_groups"]).size().groupby("idents").apply(
    lambda s: (s != 0).sum()
)
ident_samples

# %%
tumor = merged_data[merged_data.obs["tumor"]]

# %%
fig, axs = plt.subplots(1, 2, figsize= (10, 5))
with plotting_context("notebook"):
    sc.pl.dotplot(
        tumor,
        groupby= "disease_timing",
        var_names=  [
            "MACROH2A1",
            "MACROH2A2",
            "FLI1",
            "STAG2",
            "KDM1A",
            "FTL",
        ],
        gene_symbols= "gene_symbol",
        layer= "norm_scaled_genes",
        dendrogram= True,
        cmap= "bwr",
        vcenter= 0,
        show= False,
        ax= axs[0],
        swap_axes= True,
    )
    sc.pl.umap(
        tumor,
        color= "disease_timing",
        size=5,
        alpha= 0.6,
        palette= cc.glasbey_category10,
        ax= axs[1]
    )
    fig

# %%
with plotting_context("talk"):
    fig = sc.pl.umap(
        tumor,
        color= [
            "disease_timing",
            "idents",
            "MACROH2A1",
            "MACROH2A2",
            "STAG2",
            "FLI1",
            "diagnosis",
        ],
        gene_symbols= "gene_symbol",
        layer= "norm_scaled_genes",
        vmin= 0.1,
        cmap= custom_cm,
        palette= cc.glasbey_category10,
        size= 5,
        ncols= 2,
        wspace= 0.4,
        return_fig= True,
        alpha= 0.6,
    )
    for ax in fig.axes:
        ax.set_title(
            ax.get_title().replace("_", " ").title()
        )
    fig.savefig(
        "figures/tumor.png",
        bbox_inches= "tight",
    )

# %%
sc.tl.dendrogram(
    tumor,
    groupby= "leiden"
)
fig, axs = plt.subplots(ncols= 2, figsize= (10, 5))
with plotting_context("notebook"):
    sc.pl.dotplot(
        tumor,
        groupby= "leiden",
        var_names=  [
            "FLI1",
            "KDM1A",
            "MACROH2A1",
            "MACROH2A2"
        ],
        gene_symbols= "gene_symbol",
        layer= "norm_scaled_genes",
        dendrogram= True,
        cmap= "bwr",
        vcenter= 0,
        show= False,
        ax= axs[0]
    )
    sc.pl.umap(
        tumor,
        color= "leiden",
        palette= cc.glasbey_category10,
        size= 5,
        alpha= 0.6,
        ax= axs[1],
    )

# %%
sc.tl.rank_genes_groups(
    tumor,
    groupby= "disease_timing",
    layer= "log",
    method= "wilcoxon",
    mask_var= "highly_variable",
    key_added= "timing_rank_genes",
)

sc.tl.filter_rank_genes_groups(
    tumor,
    key= "timing_rank_genes",
    groupby= "disease_timing",
    key_added= "filtered_timing_rank_genes"
)

sc.tl.dendrogram(
    tumor,
    groupby= "disease_timing",
)

# %%
sc.pl.rank_genes_groups(
    tumor,
    gene_symbols= "gene_symbol",
    key= "timing_rank_genes",
)

# %%
sc.pl.rank_genes_groups_dotplot(
    tumor,
    groupby= "disease_timing",
    gene_symbols= "gene_symbol",
    layer= "norm_scaled_genes",
    key= "timing_rank_genes",
    n_genes= 20,
    cmap= "bwr",
)

# %%
cluster_genes = sc.get.rank_genes_groups_df(
        tumor, 
        group="Initial diagnosis", 
        key= "timing_rank_genes" 
    ).head(7)["names"]
cluster_genes = tumor.var.loc[cluster_genes, "gene_symbol"]
sc.pl.umap(
    tumor,
    color= [
        *cluster_genes,
        "leiden",
        "disease_timing",
    ],
    gene_symbols= "gene_symbol",
    cmap= custom_cm,
    vmin= 0.1,
    ncols= 3,
)

# %%
cluster_genes = sc.get.rank_genes_groups_df(
        tumor, 
        group="Recurrence", 
        key= "timing_rank_genes" 
    ).head(7)["names"]
cluster_genes = tumor.var.loc[cluster_genes, "gene_symbol"]
sc.pl.umap(
    tumor,
    color= [
        *cluster_genes,
        "leiden",
        "disease_timing",
    ],
    gene_symbols= "gene_symbol",
    cmap= custom_cm,
    vmin= 0.1,
    ncols= 3,
)

# %%
sc.tl.rank_genes_groups(
    merged_data,
    groupby= "diagnosis",
    layer= "log",
    method= "wilcoxon",
    mask_var= "highly_variable",
    key_added= "diag_rank_genes",
)

sc.tl.filter_rank_genes_groups(
    merged_data,
    key= "diag_rank_genes",
    groupby= "diagnosis",
    key_added= "filtered_diag_rank_genes"
)

sc.tl.dendrogram(
    merged_data,
    groupby= "diagnosis",
)

# %%
sc.pl.rank_genes_groups(
    merged_data,
    gene_symbols= "gene_symbol",
    key= "diag_rank_genes",
)

# %%
sc.pl.rank_genes_groups_dotplot(
    merged_data,
    groupby= "diagnosis",
    gene_symbols= "gene_symbol",
    layer= "norm_scaled_genes",
    key= "diag_rank_genes",
    n_genes= 20,
)

# %%
tumor.uns["rank_genes_groups_filtered"] = None
tumor.uns["filtered_timing_rank_genes"] = None

# %%
tumor.write_h5ad("data/merged_w_others_tumor.h5ad")

# %%
pb_data = sc.get.aggregate(
    merged_data,
    by= ["idents", "agg_groups", "tumor", "disease_timing"],
    func= ["sum", "count_nonzero"]
)
pb_data = pb_data[pb_data.obs["idents"].str.contains("Ewing")]
pb_data.obs["idents"] = pb_data.obs["idents"].astype(str)
pb_data.obs.loc[pb_data.obs["idents"].str.contains("Ribo"), "idents"] = "Ribo Ewing"
pb_data.obs["tumor"] = pb_data.obs["tumor"].astype(bool)
pb_data = pb_data[pb_data.obs["tumor"]]
pb_data

# %%
pb_data.obs["total_transcripts"] = pb_data.layers["sum"].sum(axis= 1)
sns.histplot(
    pb_data.obs["total_transcripts"],
    log_scale= True,
)

# %%
with plotting_context("talk"):
    fig = sc.pl.umap(
        merged_data,
        color= [
            "disease_timing",
            "diagnosis",
            "tissue_location",
            "sample_id",
            "leiden",
            "idents",
            "subsets_mito_percent",
            "sum_log",
        ],
        gene_symbols= "gene_symbol",
        layer= "norm_scaled_genes",
        vmin= 0.1,
        cmap= "jet",
        palette= cc.glasbey_category10,
        size= 5,
        ncols= 2,
        wspace= 0.5,
        return_fig= True,
        alpha= 0.6,
    )
    for ax in fig.axes:
        ax.set_title(
            ax.get_title().replace("_", " ").title()
        )

# %%
sns.swarmplot(
    pb_data.obs,
    y= "total_transcripts",
    log_scale= True,
    hue= "idents",
    x= "disease_timing",
    palette= cc.glasbey_category10,
)

# %%
ax = sns.boxplot(
    pb_data.to_df("sum").sample(30, axis= 1)
)
_ = ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation= 40, ha= "right")
ax.set_yscale("log")

# %%
pb_data.X = None
pb_data.X = pb_data.layers["sum"]

# %%
dds = DDS(
    adata= pb_data,
    design= "~ idents + disease_timing",
)

# %%
dds.vst()

# %%
pca = sk.decomposition.PCA()
pca_data = pca.fit_transform(pb_data.layers["vst_counts"])
pca_data = pd.DataFrame(pca_data)
pca_data.columns = [f"PC {i}" for i in range(1, len(pca_data.columns) + 1)]
pca_data["idents"] = pb_data.obs["idents"].values
pca_data["disease_timing"] = pb_data.obs["disease_timing"].values
pca_data["size_factors"] = pb_data.obs["size_factors"].values

# %%
sns.barplot(pca.explained_variance_ratio_[:5])

# %%
ax = sns.scatterplot(
    pca_data,
    x= "PC 1",
    y= "PC 2",
    hue= "idents",
    size= "size_factors",
    style= "disease_timing",
    palette= cc.glasbey_category10
)
ax.legend(bbox_to_anchor= (1,1))
ax.set_xlabel(f"PC1 Explained Variance: {pca.explained_variance_ratio_[0]:.2%}")
ax.set_ylabel(f"PC2 Explained Variance: {pca.explained_variance_ratio_[1]:.2%}")

# %%
fig = px.scatter_3d(
    pca_data,
    x= "PC 1",
    y= "PC 2",
    z= "PC 3",
    color= "idents",
    hover_name= "disease_timing", 
)
fig.show()

# %%
pca_data["transition"] = pca_data["PC 1"] < -100

# %%
ax = sns.scatterplot(
    pca_data,
    x= "PC 1",
    y= "PC 2",
    hue= "idents",
    size= "size_factors",
    style= "transition",
    palette= cc.glasbey_category10
)
ax.legend(bbox_to_anchor= (1,1))
ax.set_xlabel(f"PC1 Explained Variance: {pca.explained_variance_ratio_[0]:.2%}")
ax.set_ylabel(f"PC2 Explained Variance: {pca.explained_variance_ratio_[1]:.2%}")

# %%
pb_data.obs["transition"] = pca_data["transition"].values

# %%
dds = DDS(
    adata= pb_data,
    design= "~ idents + transition + disease_timing",
)
dds.vst()

# %%
dds.deseq2()

# %%
pb_data.obs

# %%
ds = DS(dds, contrast=["transition", True, False])
ds.summary()
rdf = ds.results_df
rdf["gene"] = pb_data.var["gene_symbol"]
rdf["-log(p)"] = -np.log10(rdf["padj"])

# %%
rdf["sig"] = (np.abs(rdf["log2FoldChange"]) >= 1.5) & (rdf["padj"] < 0.05)
rdf["sig"].sum()

# %%
sns.scatterplot(
    rdf,
    x= "log2FoldChange",
    y= "-log(p)",
    hue= "sig",
    palette= ["grey", "r"]
)

# %%
plot_df = rdf.sort_values("log2FoldChange", ascending= False)
plot_df = plot_df.loc[~plot_df["gene"].str.startswith("ENSG000")]
plot_df = plot_df.loc[plot_df["gene"].isin(["FLI1", "STAG2", "FTL", "KDM1A", "MACROH2A1", "MACROH2A2"])]
plot_df.head(10)

# %%
gpr = gseapy.prerank(
    rnk= rdf[["gene", "log2FoldChange"]],
    gene_sets= "MSigDB_Hallmark_2020",
)
gpr.res2d

# %%
ax = gpr.plot(
    terms= gpr.res2d.loc[gpr.res2d["FWER p-val"] < 0.05, "Term"],
    colors= cc.glasbey_category10
)

# %%
gseapy.dotplot(
    gpr.res2d,
    column= "FDR q-val",
    x= "NES",
    top_term= 20,
)

# %%
dt_wgcna = PyWGCNA.WGCNA(
    anndata= pb_data,
    name= "disease_timing",
    outputPath= "outputs/wgcna",
    species= "homo sapien"
)

# %%
dt_wgcna.preprocess()
dt_wgcna.findModules()

# %%
dt_wgcna.setMetadataColor(
    "leiden",
    dict(zip(dt_wgcna.geneExpr.obs["leiden"].unique(), cc.glasbey_category10))
)
dt_wgcna.setMetadataColor(
    "disease_timing",
    {
        "Initial diagnosis": cc.glasbey_category10[-1],
        "Recurrence": cc.glasbey_category10[-2]
    }
)
geneList = PyWGCNA.getGeneList(
    dataset= "hsapiens_gene_ensembl",
    attributes= [
        "ensembl_gene_id",
        "external_gene_name",
        "gene_biotype"
    ],
    maps= [
        "gene_id",
        "gene_name",
        "gene_biotype",
    ]

)
dt_wgcna.updateGeneInfo(
    geneList
)

# %%
dt_wgcna.analyseWGCNA()

# %%
idx = merged_data.var["gene_symbol"].str.contains("MACRO")
merged_data.var.loc[idx]

# %%
with plotting_context("talk"):
    fig = sc.pl.umap(
        merged_data,
        color= [
            "tissue_location",
            "disease_timing",
            "sample_id",
            "leiden",
            "MACROH2A1",
            "MACROH2A2",
            "FLI1",
            "STAG2",
        ],
        gene_symbols= "gene_symbol",
        layer= "norm_scaled_genes",
        color_map= custom_cm,
        palette= cc.glasbey_category10,
        size= 240000 / merged_data.n_obs,
        vmin= 0.1,
        ncols= 2,
        wspace= 0.4,
        return_fig= True,
    )
    for ax in fig.axes:
        ax.set_title(
            ax.get_title().replace("_", " ").title()
        )
    fig.savefig(
        "figures/MACRO_umap.png",
        bbox_inches= "tight",
    )

# %%
with plotting_context("talk"):
    fig, ax = plt.subplots()
    sc.pl.dotplot(
        merged_data,
        var_names= [
            "FLI1",
            "STAG2",
            "MACROH2A1",
            "MACROH2A2",
            "KDM1A",
        ],
        gene_symbols= "gene_symbol",
        groupby= "disease_timing",
        layer= "norm_scaled_genes",
        swap_axes= True,
        cmap= "bwr",
        ax= ax 
    )
    fig.savefig("figures/timing_macro_dot.png", bbox_inches= "tight")

# %%
with plotting_context("talk"):
    fig, ax = plt.subplots()
    sc.pl.dotplot(
        merged_data,
        var_names= [
            "FLI1",
            "STAG2",
            "MACROH2A1",
            "MACROH2A2",
            "KDM1A",
        ],
        gene_symbols= "gene_symbol",
        groupby= "sample_id",
        layer= "norm_scaled_genes",
        swap_axes= True,
        cmap= "bwr",
        ax= ax 
    )
    fig.savefig("figures/sample_Macro_dot.png", bbox_inches= "tight")
